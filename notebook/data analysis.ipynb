# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df=pd.read_excel('Algerian_forest_fire.xlsx',header=1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#     Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.shape
# Out:
# (247, 14)

# %%
df['month'].unique()
# Out:
# array([6, 7, 8, 9, nan, 'month'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %% [markdown]
# ## Data cleaning

# %%
df.isnull().sum()
#having missing values
# Out:
# day            1
# month          2
# year           2
# Temperature    2
# RH             2
# Ws             2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# dtype: int64

# %%
df[df.isnull().any(axis=1)] #these are missing values
# Out:
#                                day month  year Temperature   RH   Ws Rain  \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN  NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  NaN
# 168                             14     7  2012          37   37   18  0.2
#
#      FFMC   DMC      DC   ISI   BUI   FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN   NaN     NaN
# 123   NaN   NaN     NaN   NaN   NaN   NaN     NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire     NaN

# %% [markdown]
# the dataset is converted into two sets based on Region from 122th index, we can make a new column based on the Region
#
# 1 : "Bejaia Region Dataset"
#
# 2 : "Sidi-Bel Abbes Region Dataset"

# %%
df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       247 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.1+ KB

# %%
df[['Region']]=df[['Region']].astype(int)

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC    DC  ISI   BUI  FWI  \
# 242  26     9  2012          30  65  14    0  85.4   16  44.5  4.5  16.9  6.5
# 243  27     9  2012          28  87  15  4.4  41.1  6.5     8  0.1   6.2    0
# 244  28     9  2012          27  87  29  0.5  45.9  3.5   7.9  0.4   3.4  0.2
# 245  29     9  2012          24  54  18  0.1  79.7  4.3  15.2  1.7   5.1  0.7
# 246  30     9  2012          24  64  15  0.2  67.3  3.8  16.5  1.2   4.8  0.5
#
#       Classes  Region
# 242      fire       1
# 243  not fire       1
# 244  not fire       1
# 245  not fire       1
# 246  not fire       1

# %%
##removing null values
df=df.dropna().reset_index(drop=True)
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC    DC  ISI   BUI  FWI  \
# 239  26     9  2012          30  65  14    0  85.4   16  44.5  4.5  16.9  6.5
# 240  27     9  2012          28  87  15  4.4  41.1  6.5     8  0.1   6.2    0
# 241  28     9  2012          27  87  29  0.5  45.9  3.5   7.9  0.4   3.4  0.2
# 242  29     9  2012          24  54  18  0.1  79.7  4.3  15.2  1.7   5.1  0.7
# 243  30     9  2012          24  64  15  0.2  67.3  3.8  16.5  1.2   4.8  0.5
#
#       Classes  Region
# 239      fire       1
# 240  not fire       1
# 241  not fire       1
# 242  not fire       1
# 243  not fire       1

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes  Region
# 122  FWI  Classes       1

# %%
df.iloc[[168]]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC   DMC    DC  ISI   BUI  \
# 168  17     7  2012          32  81  17    0  84.6  21.1  42.3  4.7  20.9
#
#      FWI Classes  Region
# 168  7.7    fire       1

# %%
#remove 122nd rowdf.
df=df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   1     6  2012          32  71  12  0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#       Classes  Region
# 122  not fire       1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
## if we have blank space in column name we have to use
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
#have to convert numerical feature in int datatype
df[['day','month','year','Temperature','RH','Ws']]=df[['day','month','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.6+ KB

# %%
##changing other in float datatypes
obj=[features for features in df.columns if df[features].dtypes=='O']
obj
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
for i in obj:
    if i!='Classes':
        df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
##let save this cleaned this file
df.to_excel('Algerian_cleaned.xlsx',index=False)

# %%
df_copy=df.drop(['day','month','year'],axis=1)

# %%
df_copy
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI   Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5  not fire
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4  not fire
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1  not fire
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0  not fire
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5  not fire
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...       ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5      fire
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0  not fire
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2  not fire
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7  not fire
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5  not fire
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
df1=df_copy

# %%
df1.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI   Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire       0

# %%
##categories of classes,if it has to many categories of fire or not fire only because of spaces,spelling mist
df1['Classes'].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
#convert it into two only
df1['Classes']=np.where(df1['Classes'].str.contains('not fire'),0,1)
#convert categorical value in 0 & 1

# %%
df1.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
## plot density of all features
plt.style.use('ggplot')
df1.hist(bins=50,figsize=(20,15))
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
percentage=df1['Classes'].value_counts(normalize=True)*100

# %%
##ploting piechart
classlabels=["Fire","Not Fire"]
plt.figure(figsize=(12,5))
plt.pie(percentage,labels=classlabels)
plt.title('Pie charts of classes')
# Out:
# Text(0.5, 1.0, 'Pie charts of classes')

# %%
## corelation
df1.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# /tmp/ipykernel_358/4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <AxesSubplot: >

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(df['FWI'],color='green')
# Out:
# <AxesSubplot: >

# %%
df1['Classes']=np.where(df['Classes'].str.contains('not fire'),'not fire','fire')

# %%
df1.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI   Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire       0

# %%
## monthly fire analysis
dftemp=df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("fire analysis of sidi ble regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'fire analysis of sidi ble regions')

# %%
## monthly fire analysis
dftemp=df.loc[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("fire analysis  regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'fire analysis  regions')

# %% [markdown]
# ts observed that August and September had the most number of forest fires for both regions. And from the above plot of months, we can understand few things
#
# Most of the fires happened in August and very high Fires happened in only 3 months - June, July and August.
#
# Less Fires was on September

# %% [markdown]
# ## 3.0 Model Training

# %%
df['Classes'].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
## Encoding
df['Classes']=np.where(df['Classes'].str.contains("not fire"),0,1)

# %%
df1.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
#independent and dependent features
X=df1.drop('FWI',axis=1)
y=df1['FWI']

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
## Train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %% [markdown]
# # Feature Selection

# %%
## check fr multicolinearity
plt.figure(figsize=(12,8))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot: >

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                   ISI   Classes    Region
# Temperature  0.629848  0.542141  0.254549
# RH          -0.717804 -0.456876 -0.394665
# Ws          -0.023558 -0.082570 -0.199969
# Rain        -0.345707 -0.369357 -0.059022
# ...

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrix= dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])> threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_feat=correlation(X_train,0.85)

# %%
corr_feat ## both can removed
# Out:
# {'BUI', 'DC'}

# %%
#drop featrue when correlation is  more than 0.85
X_train.drop(corr_feat,axis=1,inplace=True)
X_test.drop(corr_feat,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 9), (61, 9))

# %%
#feature Scaling or Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
## Encoding
df1['Classes']=np.where(df1['Classes'].str.contains("not fire"),0,1)

# %%
X_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.62963326,
#         -1.10431526, -0.98907071],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.93058524,
#         -1.10431526,  1.01105006],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  2.7271388 ,
#          0.90553851,  1.01105006],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.06948615,
#         -1.10431526, -0.98907071],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.5973248 ,
#          0.90553851,  1.01105006],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.86113478,
#         -1.10431526, -0.98907071]])

# %%
#box plot to understand effect of standard scaler
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxenplot(data=X_train)
plt.title('X_train before scaling')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train after scaling')
# Out:
# /tmp/ipykernel_358/174383769.py:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
# Text(0.5, 1.0, 'X_train after scaling')

# %% [markdown]
# ## linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred=linreg.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print('mean absolute error',mae)
print('r2 score',score) # it has 98% accuracy best
# Out:
# mean absolute error 0.5468236465249985
# r2 score 0.9847657384266951

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
lasso=Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred=lasso.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print('mean absolute error',mae)
print('r2 score',score)
# Out:
# mean absolute error 1.133175994914409
# r2 score 0.9492020263112388

# %% [markdown]
# ## Rigdge regression

# %%
#it reduce overfitting
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print('mean absolute error',mae)
print('R2 score',score)
# Out:
# mean absolute error 0.5642305340105692
# R2 score 0.9842993364555513

# %%
# Elasticnet Regreession

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
elastic=ElasticNet()
elastic.fit(X_train_scaled,y_train)
y_pred=elastic.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print('mean absolute error',mae)
print('r2 score',score)
# Out:
# mean absolute error 1.8822353634896005
# r2 score 0.8753460589519703

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(ridge,open('ridge.pkl','wb'))

# %%
#Multicolinearty when independent features are highly correlated so need to remove extra feature which is highly correlated
